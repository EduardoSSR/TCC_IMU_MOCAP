# %%
import serial
import numpy as np
import matplotlib.pyplot as plt

# %%
ser = serial.Serial('/dev/ttyUSB1', 115200);

# %%
line = ser.readline().decode("utf-8")
print (line)
# Out:
# 17228.00	424.00	-388.00	23.92	-587.00	-341.00	-94.00

# %%
 ser.write(1)

# %%
i=0
L = 1000;

x = [];
#Ax = [];
#Ay = [];
#Az = [];

#temp =[];

#Gx = [];
#Gy = [];
#Gz = [];
              
while(i<L):
    
    line = ser.readline().decode("utf-8")
    entry = line.split("\t");
    
    
    
    AcX  = np.array(entry[0]);
    AcY  = np.array(entry[1]);
    AcZ  = np.array(entry[2]);
    
    temperature = np.array(entry[3]);
    
    GyX = np.array(entry[4]);
    GyY = np.array(entry[5]);
    GyZ = np.array(entry[6]);
    
    
    Ax.append((float(AcX)))
    #np.insert(Ax,0,AcX);
    #print(Ax)
    Ay.append((AcY));
    Az.append((AcZ));
    
    temp.append((temperature));
    
    Gx.append((GyX));
    Gy.append((GyY));
    Gz.append((GyZ));
    
    i+=1
    
#print(Ax,Ay,Az,temp,Gx,Gy,Gz);

#x1 = np.array([Ax])
#y1 = np.array([Ay])
#z1 = np.array([Az])

#t = np.array([temp])

#x2 = np.array([Gx])
#y2 = np.array([Gy])
#z2 = np.array([Gz])

#x = np.vstack((x1,y1,z1,t,x2,y2,z2))
#x = np.vstack((Ax,Ay,Az,temp,Gx,Gy,Gz))
#print(AcX)
#print(Ax)
#print(x1,y1,z1,t,x2,y2,z2)
#print(x) 
#plt.plot(x1)
#np.savetxt('Valores_IMU',(x1))
    # print ("/nAcX = ", AcX, "AcY = ", AcY , "AcZ = ", AcZ)
    
   # print("/nTemp = ", Temp)
    
   # print("/nGyX = ", GyX, "GyY = ", GyY, "GyZ = ", GyZ )
    
#x = 10*np.array(range(len(Ax)))


#plt.plot(x,Ay)
#plt.plot(x,Az)
# Out:
# 17320.00

# %%
print(Ax)
# Out:
# [array('17392.00', dtype='<U8'), array('17288.00', dtype='<U8'), array('17204.00', dtype='<U8'), array('17236.00', dtype='<U8'), array('17352.00', dtype='<U8'), array('17196.00', dtype='<U8'), array('17280.00', dtype='<U8'), array('17260.00', dtype='<U8'), array('17180.00', dtype='<U8'), array('17212.00', dtype='<U8'), array('17344.00', dtype='<U8'), array('17096.00', dtype='<U8'), array('17252.00', dtype='<U8'), array('17376.00', dtype='<U8'), array('17288.00', dtype='<U8'), array('17196.00', dtype='<U8'), array('17140.00', dtype='<U8'), array('17116.00', dtype='<U8'), array('17380.00', dtype='<U8'), array('17328.00', dtype='<U8'), array('17304.00', dtype='<U8'), array('17292.00', dtype='<U8'), array('17212.00', dtype='<U8'), array('17284.00', dtype='<U8'), array('17248.00', dtype='<U8'), array('17260.00', dtype='<U8'), array('17212.00', dtype='<U8'), array('17252.00', dtype='<U8'), array('17352.00', dtype='<U8'), array('17224.00', dtype='<U8'), array('17240.00', dtype='<U8'), array
# ...

# %%
max(Ax)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-108-887e795d1b31> in <module>()
# ----> 1 max(Ax)
#
# TypeError: '>' not supported between instances of 'float' and 'str'

# %%
x1

# %%
x2

# %%
y1

# %%
x

# %%
np.savetxt('test.out',(x1))
